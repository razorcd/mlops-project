# %%
import import_ipynb
import prepareData

prepareData.df_clean
# Out:
# importing Jupyter notebook from prepareData.ipynb
# total 2968
# drwxr-xr-x   4 cristian.dugacicu  staff      128  1 Aug 21:20 .
# drwxr-xr-x  10 cristian.dugacicu  staff      320  2 Aug 21:34 ..
# -rw-r--r--@  1 cristian.dugacicu  staff     6148  1 Aug 21:19 .DS_Store
# -rw-r--r--@  1 cristian.dugacicu  staff  1510880 19 Jul 12:45 credit_card_churn.csv
#        customer_id  customer_age gender  dependent_count  education_level  \
# 0        768805383            45      M                3                1
# 1        818770008            49      F                5                2
# 2        713982108            51      M                3                2
# 4        709106358            40      M                3                0
# 5        713061558            44      M                2                2
# ...            ...           ...    ...              ...              ...
# 10120    710841183            54      M                1                1
# ...
