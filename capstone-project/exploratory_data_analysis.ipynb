# %%
import import_ipynb
import prepareData

df_clean = prepareData.df_clean
df_clean
# Out:
#        customer_id  customer_age gender  dependent_count  education_level  \
# 0        768805383            45      M                3                1
# 1        818770008            49      F                5                2
# 2        713982108            51      M                3                2
# 4        709106358            40      M                3                0
# 5        713061558            44      M                2                2
# ...            ...           ...    ...              ...              ...
# 10120    710841183            54      M                1                1
# 10121    713899383            56      F                1                2
# 10122    772366833            50      M                2                2
# 10124    716506083            44      F                1                1
# 10126    714337233            43      F                2                2
#
#       marital_status  income_category card_category  months_on_book  \
# ...

# %%
# Show correlation between numerical types:

correlation = df_clean.corr()

import seaborn as sn
import matplotlib.pyplot as plt

plt.figure(figsize=(18, 18))
sn.heatmap(correlation, annot=True, cbar=False, linewidths=.5, cmap="YlGnBu", fmt='.2f', annot_kws={'size': 15})
plt.tick_params(axis='both', which='major', labelsize=23, labelbottom = True, bottom=True, top = True, labeltop=True, right=True, labelright=True)
plt.xticks(rotation=90) 
plt.yticks(rotation=0) 

plt.show()

# %%
import matplotlib.pyplot as plt

# pd.set_option('max_columns', None)

def plot_barh(dict, title=""):
    full_height = (len(dict.keys())) / 3
    plt.figure(figsize=(10, full_height))
    plt.gca().spines['right'].set_color('none')
    plt.gca().spines['top'].set_color('none')
    plt.title(title)
    pp = plt.barh(list(dict.keys()), list(dict.values()), align='center', alpha=0.5)

    for p in pp:
       width = p.get_width()
       plt.annotate('{}'.format(width),
          xy=(width, p.get_y()),
          xytext=(3, 6),
          textcoords="offset points",
          ha='left', va='center')
    plt.show()

# %%
record_count_by_region = df_clean.groupby(['marital_status']).size().sort_values(ascending=True).to_dict()
plot_barh(record_count_by_region, "Records count by marital_status")

# %%
record_count_by_region = df_clean.groupby(['card_category']).size().sort_values(ascending=True).to_dict()
plot_barh(record_count_by_region, "Records count by card_category")

# %%
record_count_by_region = df_clean.groupby(['gender']).size().sort_values(ascending=True).to_dict()
plot_barh(record_count_by_region, "Records count by gender")
